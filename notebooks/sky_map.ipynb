# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
plt.style.use('classic')
rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)
rc('figure', facecolor='w')
from matplotlib import cm
from astropy.io import fits, ascii
from astropy.table import Table
import astropy.coordinates as coord
import astropy.units as u
from astropy.coordinates import SkyCoord
import os

# %%
fig = plt.figure(figsize=(18,10))
ax = fig.add_subplot(111, projection="aitoff")
colors = iter(cm.jet(np.linspace(0,1,16)))

for i in range(1,16):
    num = str(i).rjust(3,'0')
    data = ascii.read(f'/home/jess/Desktop/Research/data/tess_data/target_lists/all_targets_S{num}_v1.txt')
    ra = coord.Angle(data['col5']*u.degree)
    ra = ra.wrap_at(180*u.degree)
    dec = coord.Angle(data['col6']*u.degree)
    ax.scatter(ra.radian, dec.radian, edgecolor='none', facecolor=next(colors), s=5, linewidth=.4, label=f'S{i}')

ax.set_xticklabels(['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h'])
ax.tick_params(axis='both', which='major', labelsize=15)
ax.grid(True)
plt.legend(loc='lower left', scatterpoints=1, fontsize=15)
plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
fig = plt.figure(figsize=(18,10))
ax = fig.add_subplot(111, projection="aitoff")
colors = iter(cm.jet(np.linspace(0,1,16)))

for i in range(1,16):
    data = pd.read_csv(f'/home/jess/Desktop/Research/data/tess_data/simbad/known_ebs/simbad_sector{i}.csv')
    ra = coord.Angle(data['RA']*u.degree)
    ra = ra.wrap_at(180*u.degree)
    dec = coord.Angle(data['Dec']*u.degree)
    ax.scatter(ra.radian, dec.radian, edgecolor='none', facecolor=next(colors), s=10, linewidth=.4, label=f'S{i}: {len(ra)}')

ax.set_xticklabels(['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h'])
ax.tick_params(axis='both', which='major', labelsize=15)
ax.grid(True)
plt.legend(loc='lower left', scatterpoints=1, fontsize=15)
plt.show()
